# %% [markdown]
# ### 1. Mount Google Drive
# We will mount your Google Drive to make the target path accessible inside the environment.

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. Locate Shared Folder and Create Datasets Directory
# To target the shared folder link you provided, you should first add a shortcut of that folder (`1aiv3LEd7IiuHy5pMXOvkS6avUsH8d7aJ`) to your **'My Drive'** (right-click the folder in Drive -> *Add shortcut* -> *My Drive*). Let's define the path and create the `datasets` folder.

# %%
# Define parent path in your Google Drive.
# If you added a shortcut of the folder to your My Drive, replace 'YourShortcutFolderName' with its actual name.
# Or, if this folder is directly in your Drive, specify its parent path.

parent_path = "/content/drive/MyDrive"
target_dir = os.path.join(parent_path, "datasets")

os.makedirs(target_dir, exist_ok=True)
print(f"Target datasets path initialized: {target_dir}")
# Out:
# Target datasets path initialized: /content/drive/MyDrive/datasets

# %% [markdown]
# ### 3. Install Requirements and Download Datasets
# Now we will install the packages and download each dataset directly into subdirectories inside the designated Google Drive `datasets` folder.

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 23.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 67.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 87.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typer
#     Found existing installation: typer 0.27.2
#     Uninstalling typer-0.27.2:
#       Successfully uninstalled typer-0.27.2
# ...

# %%
from roboflow import Roboflow

# Dataset 1: BD Road Sign
os.chdir(target_dir)
rf1 = Roboflow(api_key="3qduNDzsBSXEa73QGWfB")
project1 = rf1.workspace("hailhydra").project("bd-road-sign-dataset-creation-pznqx")
version1 = project1.version(1)
dataset1 = version1.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to BD-Road-Sign-Dataset-Creation-1 in yolov11:: 100%|██████████| 1904/1904 [00:24<00:00, 78.76it/s]

# %%
# Dataset 2: Household
os.chdir(target_dir)
rf2 = Roboflow(api_key="3qduNDzsBSXEa73QGWfB")
project2 = rf2.workspace("household-j10i9").project("household-khbd4")
version2 = project2.version(1)
dataset2 = version2.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to household-1 in yolov11:: 100%|██████████| 47162/47162 [14:27<00:00, 54.35it/s]

# %%
# Dataset 3: Traffic Bangladesh
os.chdir(target_dir)
rf3 = Roboflow(api_key="Y1GMNsMSqM91BzRdxF18")
project3 = rf3.workspace("traffic-6kfw3").project("traffic-bangladesh-hail-hydra")
version3 = project3.version(6)
dataset3 = version3.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-Bangladesh-Hail-Hydra-6 in yolov11:: 100%|██████████| 29140/29140 [10:28<00:00, 46.36it/s]

# %%
# !pip install huggingface_hub

import os
from huggingface_hub import snapshot_download

# Define target directory inside Google Drive datasets folder
hf_dataset_dir = os.path.join(target_dir, "BanglaBoro")
os.makedirs(hf_dataset_dir, exist_ok=True)

print(f"Downloading BanglaBoro dataset to: {hf_dataset_dir}")

snapshot_download(
    repo_id="SrejonAhamed/BanglaBoro",
    repo_type="dataset",
    local_dir=hf_dataset_dir
)
# Out:
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# '/content/drive/MyDrive/datasets/BanglaBoro'
